# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>
# <br></br>
# <br></br>
#
# ## *Data Science Unit 4 Sprint 3 Assignment 1*
#
# # Recurrent Neural Networks and Long Short Term Memory (LSTM)
#
# ![Monkey at a typewriter](https://upload.wikimedia.org/wikipedia/commons/thumb/3/3c/Chimpanzee_seated_at_typewriter.jpg/603px-Chimpanzee_seated_at_typewriter.jpg)
#
# It is said that [infinite monkeys typing for an infinite amount of time](https://en.wikipedia.org/wiki/Infinite_monkey_theorem) will eventually type, among other things, the complete works of Wiliam Shakespeare. Let's see if we can get there a bit faster, with the power of Recurrent Neural Networks and LSTM.
#
# This text file contains the complete works of Shakespeare: https://www.gutenberg.org/files/100/100-0.txt
#
# Use it as training data for an RNN - you can keep it simple and train character level, and that is suggested as an initial approach.
#
# Then, use that trained RNN to generate Shakespearean-ish text. Your goal - a function that can take, as an argument, the size of text (e.g. number of characters or lines) to generate, and returns generated text of that size.
#
# Note - Shakespeare wrote an awful lot. It's OK, especially initially, to sample/use smaller data and parameters, so you can have a tighter feedback loop when you're trying to get things running. Then, once you've got a proof of concept - start pushing it more!

# %%
from tensorflow.keras.callbacks import LambdaCallback
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
from tensorflow.keras.optimizers import RMSprop

import pandas as pd
import numpy as np
import random
import sys
import os

# %%
df = pd.read_csv('https://raw.githubusercontent.com/JimKing100/DS-Unit-4-Sprint-3-Deep-Learning/master/module1-rnn-and-lstm/sonnets.csv',
                 sep = '\n', header = None)
df.head()
# Out:
#                                              0
# 0                                            1
# 1   From fairest creatures we desire increase,
# 2  That thereby beauty’s rose might never die,
# 3     But as the riper should by time decease,
# 4       His tender heir might bear his memory:

# %%
# Encode Data as Chars
text = " ".join(df[0].tolist())
chars = list(set(text))

char_int = {c:i for i,c in enumerate(chars)}
int_char = {i:c for i,c in enumerate(chars)}

# %% [markdown]
# # Resources and Stretch Goals

# %%
len(chars)
# Out:
# 71

# %%
# Create the Sequence Data
# The lists are: encoded (chars encoded as integers)
#                sequences (40 chars per entry)
#                next_chars ()
maxlen = 40
step = 5

encoded = [char_int[c] for c in text]

sequences = [] # Each element is 40 chars long
next_chars = [] # One element for each sequence for prediction

for i in range(0, len(encoded) - maxlen, step):
    sequences.append(encoded[i : i + maxlen])
    next_chars.append(encoded[i + maxlen])
    
print('sequences', len(sequences))
# Out:
# sequences 18950

# %%
# Specify x & y - 3D matrix

# Initialize arrays with False
x = np.zeros((len(sequences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sequences), len(chars)), dtype=np.bool)

for i, sequence in enumerate(sequences):
    for t, char in enumerate(sequence):
        x[i,t,char] = 1
        
    y[i, next_chars[i]] = 1

# %%
# build the model: a single LSTM
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars)))) #input shape of a singular observ.
model.add(Dense(len(chars), activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam')
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0209 11:18:06.673053 4374568384 deprecation.py:506] From /Users/JKMacBook/opt/anaconda3/envs/NN/lib/python3.7/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
def on_epoch_end(epoch, _):
    # Function invoked at end of each epoch. Prints generated text.
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_int[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = int_char[next_index]

            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

# %%
model.fit(x, y,
          batch_size=128,
          epochs=20,
          callbacks=[print_callback])
# Out:
# Epoch 1/20
# 18944/18950 [============================>.] - ETA: 0s - loss: 2.9141
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: "your feature.   Incapable of more, reple"
# your feature.   Incapable of more, reple th the s t t o te  o e to the tr te the th th the the t the t t re to the t r te t th tie she te tin th ther th the te t the t the t the the  the s th se te the t t  te t te  t e t t  t t t t t the the t the th s the t  te the te t t t t t re te the t the tr th te the  te the te to t to te t the t the thee  te t the the he t the the t t the ti t t te t the te te t s  t t the re t te the to the t
# ----- diversity: 0.5
# ----- Generating with seed: "your feature.   Incapable of more, reple"
# your feature.   Incapable of more, repleum ore rs hee  ven th th tind e s n i tre  rieil ito ro  ie ehe t teise ottd sen reos ohn sin st t eoat  minon tolwtr Wo ttorae feh  n te eoiho ile bbecr the  tite tll rs he tet ea me nts r sor tyed s ol he s  hee te ireot t loee tn fye tir ro , lrho n coT he y, wod  ne thle rh sse  re  tennerg s te vhe  he he oo f tid th ro tooo tir trthee te toar  ir rert totre to e tr ve r oin t the sog e r te
# ----- diversity: 1.0
# ----- Generating with seed: "your feature.   Incapable of more, reple"
# your feature.   Incapable of more, replembwe,ikes oofswr r ooetheooh lris  oseere, os e s, m ttelutae ,cfcntyomvmdee seit y o aTmrs d r rha er t inwlehthmthed,r, to,brrs  g ilfeyaddeuc e rtpi se  twouev tmtsrtwinglud e,athoielltuitpdch t, lnoan stoaryl precwoeeoe.n seth b ssskceor’tllnohh hresh,ino4r dJeae ct,,n dletni, sreew yol sayoBee,rii nhee m adot rnrro eunelenn hyewt nre wcs arsr n rut,,pwey th hiioys obptstoareceg eatnet lh,hirc
# ----- diversity: 1.2
# ----- Generating with seed: "your feature.   Incapable of more, reple"
# your feature.   Incapable of more, repleass tclf fWtenwiechsrioushngy y tIyei tFdwdsnosaifnsN sn;bw Lro es:u, I,eru iltn t  mivky krc sth’itssar pnre rgiIre hessM0at.dl’ v0ne bo n ttispe,dorrymdkoAIndoshoovslwg bi ehi dor heef,r aNsrtt  thifeot khcoedcdWyd f Atp Wr ied fjO eothJad ot Tevh Iyi tie,anendken3F WTkr ttoo qTy, nofittsxWovondryaieoreMT(Bo helre ir;cLnoyy  o:ncve rl le ru T,eum )teshsrrr bo yeG deeh ATam ’otcildsef.n r ieo cpa
# 18950/18950 [==============================] - 61s 3ms/sample - loss: 2.9142
# Epoch 2/20
# 18944/18950 [============================>.] - ETA: 0s - loss: 2.6971
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "ll doth grow. 116 Let me not to the marr"
# ll doth grow. 116 Let me not to the marr the the the the the the the the the the the so the the the so s the the the the the so the the the the the the the se the the the the me the the the the the the the the the  he the the the the the me the the the the the the the the th ne the the the the the the  oo the the the to the the the the the the the me the the the the the the the the the the the to the ain the me so the to the the the the
# ----- diversity: 0.5
# ----- Generating with seed: "ll doth grow. 116 Let me not to the marr"
# ll doth grow. 116 Let me not to the marr stt athe  he le mare thee the ns whe the th res eoee sen ther he the m so the rh so nh ne then the  ont togh thoh ta iop that iee win ane me fo th rer tht no the ne son mn me s te be ion of lo souil me th mons hoo ale, sot aor woos those th de yo the that sd all,  nee the ton th do the toars re the  hee bnt tu tot t fr ne to med  o them sun co thid thes ne thase in lo ber tote sed whe me eih ce m
# ----- diversity: 1.0
# ----- Generating with seed: "ll doth grow. 116 Let me not to the marr"
# ll doth grow. 116 Let me not to the marr het n riiopk Thuy tta wairee rT, ao teadd  cetant iw plne sossty wrBtme xheaiov sle ht toce wetcd bte wecd d tosl  anhes mig h nnosnrnspsfmlo d sd te t aild try on, theiww ty ws doex fe y rt Woeui aiie een n liin nihesp o toers td nherd, mafes thrs ineto mhen dhe th sn rh be fiTh oklr metwaeHns m, dk  l me aBd mysis thes cu Ia, de, al ty d reye rith bewmvin conf ndclm f-lor nIod sm he lothew dose
# ----- diversity: 1.2
# ----- Generating with seed: "ll doth grow. 116 Let me not to the marr"
# ll doth grow. 116 Let me not to the marrdtrurpre ne amiws tatrw wcami trH nhreldoyutlor ce  lsaid,t Wha n ige,ebe beeut n!,i tehstu bye m1,shTynibetlh hs gte4 hsis a lesauasay the,ryl d rfe ayl oern o fit.rmd, 6i yt;ad nh thntc n reds iures, enen fon z,I g. boSn ToL t whyI,  qanoeou ond beisueh ro,, miilre ueoAh wownr psargtisidachmkld Ohlfatva hel Aotike moned snWUtst phu’ ,ele to’sh n rs dAl oyheblgc stIwnoc tyinid ulrdW hNr, ose heti
# 18950/18950 [==============================] - 63s 3ms/sample - loss: 2.6971
# Epoch 3/20
# 18944/18950 [============================>.] - ETA: 0s - loss: 2.5408
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: "gone. 72 O lest the world should task yo"
# gone. 72 O lest the world should task yout the the thee the the the the the the the the the the ther the thes thes thes thes the thes the thet the the ther thes ther the thes the the the the then ther the the the the ther sore he ther the thes thes the thes the the ther thet ther ther the the the ther the the thes the the the the thes the the ther the the the thes rout thes the the the thes mon the the the the the the there thes the the
# ----- diversity: 0.5
# ----- Generating with seed: "gone. 72 O lest the world should task yo"
# gone. 72 O lest the world should task yous po thes sel rhais tint in thy thethe, sore theior ahed trond s thein thos ins, she fed thise me see londe heth the fere hot thee thet tore ne thest mes the the thy me thes nee iine sare m ine th eis anl thet thes the thes tho thes bawteut to th th thathar theu thont the uee tindes poal moa thos both thes the sin then the the there pere see, therr beall eos bothee  he eor thes liuh s the thef so
# ----- diversity: 1.0
# ----- Generating with seed: "gone. 72 O lest the world should task yo"
# gone. 72 O lest the world should task yo’ceorush tNy heriblbars sine thes wir qgins hos fon  ahe. iaseluSmes mejoixe Iave celigedat iy me hasgon (aeailtheserdfrrarr ahlthjine, . dtsacaTtsh, thip tht, fan lhey dehetd roaOh itinstoyus t aregheWnis triro fonse befoe cnhoflt Iatd whaer fott aalglan swrauglen,.duts wind thaugnhmegtitwelnset, tashey As tyt touv. fleltr kn woase rant aIs soit sroyeikis be mdnss, ivec, vyits sfarels fhreletnd b
# ----- diversity: 1.2
# ----- Generating with seed: "gone. 72 O lest the world should task yo"
# gone. 72 O lest the world should task yo:hoer nie8, ko1t lle Tle mnty mf;e, ,arvegcithoiMahe faAigt thimrge t’ed woaemet1An, huu,v vesd ahictig.yd my.tb rrio so tprlmellA mlruaude tngeond ghBy soct mamFobnsfmnve,fOBthancctbrtheee td dpy,touryhtos 7vates ;o 6inrd tomabwoumicld meh Ihansisoel daiWakv Iy thedet cot thiegt.eyd: tmed, Buc’R wyws’iseu Wlirh wns hhf,c rtr, hiFume ghee Sal3 jh ordetsin sosreuthelrcskest yotridTmedacas brat ille
# 18950/18950 [==============================] - 64s 3ms/sample - loss: 2.5406
# Epoch 4/20
# 18944/18950 [============================>.] - ETA: 0s - loss: 2.4327
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: "e, Art left the prey of every vulgar thi"
# e, Art left the prey of every vulgar thin the the the the the the the the the the the the the me the the the the the the the the the thar that the the the the the the the the the the the the the whe the he the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the me the the the the the the the the the the the the the the the the the the the the the the the the the the
# ----- diversity: 0.5
# ----- Generating with seed: "e, Art left the prey of every vulgar thi"
# e, Art left the prey of every vulgar thid the dear phar the bt thy mow the d the to the che the in on do beit the n the he sou hot gor whate the  ho the thar ghas  han the  he for hid the that  ait or mer the tho he bre the the  oe than shy whes in  oon the th the wor thar wh thee rhre the than the to ther dhat the than thee the th the be the the bee wod liche at thel th s the rou th ar fer that th ne sout than the tou the thas mor  he
# ----- diversity: 1.0
# ----- Generating with seed: "e, Art left the prey of every vulgar thi"
# e, Art left the prey of every vulgar thine or thaues afae Whealk daI tfund coveres medncos sof fat, Htov  rinen hnou I me ring tof gmaicd beaP hanu, wimo  isng anow ut um, mo bile bet baw sre paed, basvse tha’ thyis matyh yoad the hono nhukham lnat bil heprt hertgof eir laol eod foc wich apen, af tiil ched th nn innB ut iud Ang dans dafrta thone , borean. 1nd vet aokurd wange mancPou2 aafWhe this in hice, Tosis ap  ar ro kidr pemeriy hh
# ----- diversity: 1.2
# ----- Generating with seed: "e, Art left the prey of every vulgar thi"
# e, Art left the prey of every vulgar thire.  moIe  hoaf te aw nd the, Anel wwrad Hte srece Bbem bged pryeuupavlo  ity I thas Fnd moucc weve   ir f bese bode thonw Thetou garsthece tokd’d g eilt masdy Woeway sor mwnlrthec dy1ur thet: Bathor ?fn soe ttuuiR wokfoWh Wunr’e, toutotd fhedrn. Be, go wo h fou d lgrnehe Redd(, al fohn, ghlwhand orSsFdsd 3hloirw der th sesm rore iho gom wfdowd bose ther  aith thy phe Nelrrlpzun ghte ste hgh  urlk
# 18950/18950 [==============================] - 59s 3ms/sample - loss: 2.4328
# Epoch 5/20
# 18944/18950 [============================>.] - ETA: 0s - loss: 2.3605
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: "stial face, And from the forlorn world h"
# stial face, And from the forlorn world hou the the the the the the the the the the the the the the the the the the the the the the the thand the the the the the the the the the the the the sere the the the the the sout the the thy the the the than the the the the the the the the the the the the the the the the the the the then the the the the the the the than the the the the the the the the the the be the sean the the the that the the t
# ----- diversity: 0.5
# ----- Generating with seed: "stial face, And from the forlorn world h"
# stial face, And from the forlorn world hor that tout thor sol t in wiigh sour ne mou the thou wan thran the thy woult ind the heau con thar,  oy soar thins barest ho me thy ther wous bou the son thes mo they wound thans so ner me sore the theind that the so the thou lind bor the found bet mat theute theud mout loth fout sou the sout the ther fand and tous tove the ghy sein the the the sore eno ind poot thous thy woan tit mee thil thy th
# ----- diversity: 1.0
# ----- Generating with seed: "stial face, And from the forlorn world h"
# stial face, And from the forlorn world he 1y tars’s thit caoc yortwf thinges th I saut, Whond pst sou ghal kppungicd ense, Woim siple, davl or ang jotharpll, Wot efy gorot in tnnb mos) lll’sd kede waerrcond, Acs vendl hh seay tour miu. n of coun hrend out.  ,ldin hemid fout hod hay moms Ga peach  rote, wuin she paane, Srom hevs oollanghilh, Tuan sainm coaiL Hue spetige, poaue mow th whats mulv, dd Srong love  ao mouthesd thewo. th sebee
# ----- diversity: 1.2
# ----- Generating with seed: "stial face, And from the forlorn world h"
# stial face, And from the forlorn world hepgr2Mute Bey m meke thas onr Vugimaute hniwydey mud m3ce,, maoreu theid moe, Ath;t rrarf wotn cora foinB, Wpond thye, W’n thy tmtiovesled Uos ydsao oT nTay Ie chabr qf rpert thisg?t d themlt bide D lou, Ot nkos hiveg momh faslnH ’afls o tpue siegine, co hnmiw, b)are to syy Wne tea we mn stheapwes woasS Ulos puont mont wptte tete, s houghjul  Or lase thedd anee a4 Ii ther helake, pulldrey the Phes
# 18950/18950 [==============================] - 56s 3ms/sample - loss: 2.3605
# Epoch 6/20
# 18944/18950 [============================>.] - ETA: 0s - loss: 2.3037
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: "nkindness shaken As I by yours, y’have p"
# nkindness shaken As I by yours, y’have pout the the the that the the the the the the the the than the the thar the the the the sind the the the the me the the the the that the thar the the the the thar the the the the the the the the the the the seer the the the the the thar the the the the the the the the the the the the the the the the the the the sor the the the the the the the the the the the me the the the the the thas the the the
# ----- diversity: 0.5
# ----- Generating with seed: "nkindness shaken As I by yours, y’have p"
# nkindness shaken As I by yours, y’have pole me an faret ball, yor thoul thy suth thou my thouf thae fou mein lin the thau the be ain the  he thal thas is one whit me sise I sher mell sore sor and thar dour mout the mes the tor deand I me mo dore to the tha she hes hire the mour weres thur soun an the sut whe soung And for ther mat goare, And wo tho mens my mor me the hes and mar my the y alre lor art thy where rot my seor siine dou, be
# ----- diversity: 1.0
# ----- Generating with seed: "nkindness shaken As I by yours, y’have p"
# nkindness shaken As I by yours, y’have pswhis lhe, th al elinh mees, Lalt woulllt oinuitwary mov the ke tho pan tmy ouB oade noi hoasI , Anthake. G Tu thr, Thine, wind, Oand Shain hat  ham thAe thon nof Thae dick inthin nit  hens rueved, uncou 8ind coew hy suom ouve. d  s wein ty Whyus Whil saf meue ls mo the ar, aum game suove dnece ;os math,  if cin thek bater A-me, 4e ust. s mraxlninge,   ar Of nou theue.  2art irts, bunfaf? thaslrel
# ----- diversity: 1.2
# ----- Generating with seed: "nkindness shaken As I by yours, y’have p"
# nkindness shaken As I by yours, y’have pyheet ae s ot ind wetI  Towlard parmith sousa. Joes ranot a lik ont mof hfia. d waf By ann ineeF, Iosd Somy r cor tpitr tfend oO Themerttdjop’st: no H the gy pels ilesedte gorys Wtyend k Descreise weaEsiigbf buf’s rey do thar mees  jy’er de. rthouFope enturss w yush theare, (ocare chirttenichyo. h,: O w huwU tiecech whamed teaid Wfr,rLSice.  alvtat ge dureht  Mm sher tI Whos Bf asg nuamte hoomlxdn
# 18950/18950 [==============================] - 64s 3ms/sample - loss: 2.3038
# Epoch 7/20
# 18944/18950 [============================>.] - ETA: 0s - loss: 2.2576
# ----- Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: " their praises are but prophecies Of thi"
#  their praises are but prophecies Of thin the the than thar the that the that the thas the that the thou the the me the the the the the that the ther the the the that the the the the that the the the ther that the the thin the the the thar the the the than the the the the that that that the ther that the the thou the thar thou the the thar thar the the the the the thar that the the the the that that the the the the the the the the the t
# ----- diversity: 0.5
# ----- Generating with seed: " their praises are but prophecies Of thi"
#  their praises are but prophecies Of this thout the thar the thy sof lein, y all all soull sat thee rened being the best ther sied the gove ther math biche that thy thar math the tor seare sore the then this that the sail the thas thin the me thas outh that the ha this in oure thath fang bert ther co thit thy sathe tert that teind an thy muth ther the the then that the sin roume thy mine sait thin thel thes I deathe thar thou hesill be
# ----- diversity: 1.0
# ----- Generating with seed: " their praises are but prophecies Of thi"
#  their praises are but prophecies Of thimy onhe . dhalfort irire, Tharve rot anvtith s aithans these arut and, menuar de thel the ias po-mot the gne neinm -iyhanpgh uotve sare Llcere brirt foul mas thed ssicer mf’cy mane, Whithy Afai) maded tser ta aitg: mandoxghoe wits puees, eo dlo de whis oiLeden, pessellt, nuansed, p Yerwen bnse dilet  wheT the ro’ menk weert. n4 Tiist, . masel irinl tho’s.   if thyew tor) Sor fol thit thell wham my
# ----- diversity: 1.2
# ----- Generating with seed: " their praises are but prophecies Of thi"
#  their praises are but prophecies Of thiust, Woale’s, froWbced,. Tar t(ek dato ho soewlosfte tols that (tint rte thel Greg, rhteve, ’nath gyaas thut ser jit falr eifaweths bastis the bougrc cheo hiniss Whemr huetM slemy sice bellpgeras haieo. As my priert Wror whand’M thang owror birg eailg fomeows eath ihk lithike f(lastis yor the mithendzasts6ghencsy icectere m mbeve thiciths ie totho  hepefoTh sosy sseearindad? Thas male ns hovogjnde
# 18950/18950 [==============================] - 63s 3ms/sample - loss: 2.2577
# Epoch 8/20
# 18944/18950 [============================>.] - ETA: 0s - loss: 2.2183
# ----- Generating text after Epoch: 7
# ----- diversity: 0.2
# ----- Generating with seed: "of a former child! O that record could w"
# of a former child! O that record could wor the the the me the the sore the the the the the the the the the the the the the the the the the wher thar seare the the thar the the the the the me the the the the the the the the the the the the the seare the the the the selle sour the the the seare seere wine sor in the the the the the the the the be the the the the the the the the the the the the be the the the the the the tor ther sore sill
# ----- diversity: 0.5
# ----- Generating with seed: "of a former child! O that record could w"
# of a former child! O that record could whas the sore bath ther palld, deor ther int onder the thou ghe than dound thou in be ther seree the math the woel, mare, That that on in lour sor arghe seoin sas th sore, Or thee, Whar sy ore wile the sare the thas ling thes the rive, Ar wand be mes the the ly ur thane thy the, the thy thet the the mon, beee fear dome ne, And thou be thaur is bou the fall loul thes soind woth sikes me wite thar th
# ----- diversity: 1.0
# ----- Generating with seed: "of a former child! O that record could w"
# of a former child! O that record could way hons, 3e mat thouy fif tin: d eeases. Ball eive, Theur worperd brrut try bsy’stice o  bemy best ouith tut mef ronle. I Oh beart wirceuce: n as yekly, And cpecow be ar oh bans, AI dod int ne ir lnet’s Gr line. Ffnotper bnd peaf so cly woy ie las wine the aed, rOo peqmyy aighe, Ar afar hond weenhof sserris,, I 2erlacmat ince, hou biche, Muinges, 2i thouven am be ey af thow but ajuthop is haed tuy
# ----- diversity: 1.2
# ----- Generating with seed: "of a former child! O that record could w"
# of a former child! O that record could woucess shat lonf Iy byufe toaw eplo laveles puye. 2a euran: theueou hrd llr alld, anroorw, wpous me. stavet yare, d’pentfell es min dr yrwirpfadll beace m bo. e frote, In ceother An slothas? Ine bay, temw fin y hee mime,  aWwallnt Mtas, andmuf eratmr se’sis duch te lceteit wourgrmy fomlu I af mouer souu, Foe , Will mlee pall dou, y Nor n now, I thalk lian caykee,  weat seen h towlow tyo voithe hgh
# 18950/18950 [==============================] - 56s 3ms/sample - loss: 2.2180
# Epoch 9/20
# 18944/18950 [============================>.] - ETA: 0s - loss: 2.1850
# ----- Generating text after Epoch: 8
# ----- diversity: 0.2
# ----- Generating with seed: "Unthrifty loveliness why dost thou spend"
# Unthrifty loveliness why dost thou spend the the the be the the the the the the the the the the the the the the the the the the the the my the the the the the seat the the the the the she in the the the the me the the the the with the the the the the the the me the the thit the the the the the the the the the that the the the the the the the the the the the the the the the the the the the the the the the the the the me the the that the
# ----- diversity: 0.5
# ----- Generating with seed: "Unthrifty loveliness why dost thou spend"
# Unthrifty loveliness why dost thou spend you in brers thel an the bed me my seath than the the ared dour wing choull be cons the ye fait the lour be son that thine shint whe to the dore routh the than to mis the sind fart of pall wham chis the beers the I the thingee my more wame hou co the thes and the cor my seint wound beout hout meve thee the the douss this the eothing on thin wor som oud this the me the hich the s art on the the do
# ----- diversity: 1.0
# ----- Generating with seed: "Unthrifty loveliness why dost thou spend"
# Unthrifty loveliness why dost thou spend ofhe ilive deand mouff hisege. AnTher thar of fithfer dols wart , the dytiln thit, as ones’s, ‘us binthe mede kost the sove, Uf chige,y Whicee werlles nuf ind what nich reesteind’ece bo gite lins’g brgets d4 leit, lowene or mf peine,, Tha cod lenerd jronmut I ldese the maecd cact toend bo barer wiy thy breis by’w clites  wfan tow bmenkpa’g, The wof dame 7ave Thou sh lavledy ho douvlt whee orptit
# ----- diversity: 1.2
# ----- Generating with seed: "Unthrifty loveliness why dost thou spend"
# Unthrifty loveliness why dost thou spendide rrsgto thye (iooth’st? cotlist ;onthats  I shed, But I nf bly bry Me-? womt minge. beog f I shind ganesuc. T nhen sote so sheaw, 6 Ol pefmeer I yekees corko, I outh. My caragp peamguitte6. Ty Thes wllom? Lorrd, Thoud yakY i raand, No th cSeed ho m, Wodsos nytingow arin whavewy Thaing sis singnrcrcerce hove fof deib be pard ghate andhl  fadmen thavitath’ ourtto Saane:icho0 ty urighyud olnge, Wh
# 18950/18950 [==============================] - 57s 3ms/sample - loss: 2.1848
# Epoch 10/20
# 18944/18950 [============================>.] - ETA: 0s - loss: 2.1532
# ----- Generating text after Epoch: 9
# ----- diversity: 0.2
# ----- Generating with seed: "this, and this with thee remains. 75 So "
# this, and this with thee remains. 75 So the my math the be me my wore the the me the the the the the the thou be the the the the math my are the the the the that my me the the the the the the the the sout the the the the in the the in the the the the the the be the the the the the the the soun thou he in the the the thou the in the the the the the that the thou be thee be the the the the the the the the thou hour the the the the the the
# ----- diversity: 0.5
# ----- Generating with seed: "this, and this with thee remains. 75 So "
# this, and this with thee remains. 75 So the with no hot or where sour aot and thee sare the the wou the be atht tith aine han wor womy dothe ond than thith of with seared on the fath soan of sor sealt the fore toat my worthe hove for gat and ang thes wore sour sot thee wine fond I teith with an my and thy bethe for too thou deme,   thich ace thy terethind of thou stout the counge be this thy mall to love tall than to thee the an me tour
# ----- diversity: 1.0
# ----- Generating with seed: "this, and this with thee remains. 75 So "
# this, and this with thee remains. 75 So hwe, Oo raes, priot ay aidowreare thou dofall, And tocuse, Bu my wrye loMst in pill thy mouwe’s Ores I lyairseor-th, ied wofk the ronge slake theist wiot an my woule’s bithn tor tili keis cote tLen thut syese, and faln me int frawe nosow tist doar gees meate, bensegale nore seli, Bis fof pand hovt cstellatl mingce the lens pinsts ande, Praru sitt forde shes Iyve, not suly pives, Mad with yowy bidg
# ----- diversity: 1.2
# ----- Generating with seed: "this, and this with thee remains. 75 So "
# this, and this with thee remains. 75 So tout ondoskpin’on-inc eogsth9 rhamitssedowe. in thferereces owlldenu, Whes hoches in ceoun, Sroroullvibr ahst be thou. S!le sow? tacs one sfto ceist y sull: ar-yraugeeed seigma seekl, make sonn wayh, uw, Lat ofich re beour wom, 4ono wo thinesungernstysedels, Iny dof dike yueedve snreffe’ser: tgoukeed. 2oun  arssugt of u ay the une hirt,u  Lefraveutr thou Ghit ljepbore, Mwot nhes med, And Cedorehwc
# 18950/18950 [==============================] - 60s 3ms/sample - loss: 2.1531
# Epoch 11/20
# 18944/18950 [============================>.] - ETA: 0s - loss: 2.1290
# ----- Generating text after Epoch: 10
# ----- diversity: 0.2
# ----- Generating with seed: "e, A dearer birth than this his love had"
# e, A dearer birth than this his love had the the the the the my my sine sead the the the the the the my seare the the the the the my sore, The the the the the the the love the the the the the with the my in that my ming the the the love the the the the dour the the the my the the the my the my and the the my sore the the with the wing the the the the the the the the the the the that seare the the the sore the thin the the the that the t
# ----- diversity: 0.5
# ----- Generating with seed: "e, A dearer birth than this his love had"
# e, A dearer birth than this his love had co the dor sted shee, For somer ar were or to than thas sting the dowe the the thou dom my meed that in parth se my cuy the hes be the the the me thit thour bot re bear sing the Whes be thy and ant thin the than is the bare hese sene to in the this thou the  hall sstill wich be not thar that the my but wores that wore weand wore the my wind ros in thit meer to co hill ghen so math mour the famy s
# ----- diversity: 1.0
# ----- Generating with seed: "e, A dearer birth than this his love had"
# e, A dearer birth than this his love hadp theifr, nuthe the tiall) wirtbus Iindy moir tis sise bee, for wineis tert mo cove bonve whyeall me owcong’s farkonr’s bat beis thouessise erewhey aur cay mile and in the love sot un the , ar thes dorddayt dor3 in my conght  ist ond lour my meal, diys mace poves onlead bad s the dterads you ced sist meon’s yolin eino thice tate Whive? . nris k lich thou drows thel winr ole ass. mor mine preay tho
# ----- diversity: 1.2
# ----- Generating with seed: "e, A dearer birth than this his love had"
# e, A dearer birth than this his love hady golk mueo te, nod, ware not, arows, Thmce cakunsw sxill de rren tees Soust, theer taic, ) 6ckerot gsliki’s nack? I I wonen. I Satr ntyur-repvesss, doe snimy beveand wrase vyey as Lowce tracapstter’? Whate, Mu cfaifak w4taec in trtoufifis an tinn, Hove the, 3lont winse I7 bpreere’s Sist foli hat Pass sineed bsgoot s tat ah thim doplgpes weanis woel dacth warlemrs? O Ym! thu allvef or eakbey Thed
# 18950/18950 [==============================] - 58s 3ms/sample - loss: 2.1291
# Epoch 12/20
# 18944/18950 [============================>.] - ETA: 0s - loss: 2.1031
# ----- Generating text after Epoch: 11
# ----- diversity: 0.2
# ----- Generating with seed: "hemselves their pride lies buried, For a"
# hemselves their pride lies buried, For and the thou hat the thou the the the that and the the with the the the the the the the thou he the the the the the that the the the the the the my me the thy my wher the shen the the thou hour the wor the the the the be the thou the the the with the the the the that the the the my and the the with the when the the the with that the the the the with the the the the the the the the the with the love
# ----- diversity: 0.5
# ----- Generating with seed: "hemselves their pride lies buried, For a"
# hemselves their pride lies buried, For and that to ghy meaks the thart fom the rore houll my mared to than thour my ther wit that whes dourt thy I thy thy love the ris the prevere the then the live love the my mered me eor hour, And dow me the roud the I the cest the rich and the thou doust the the moul shy mave thou heame an wor hour, Why wo hee the lave pat ing the raine my mave sime hat that be thou how thee or way for my thou my mic
# ----- diversity: 1.0
# ----- Generating with seed: "hemselves their pride lies buried, For a"
# hemselves their pride lies buried, For ar hichouth bree, Andwind, th ruke whok os ; wne douk, Thou court: 1hrar thius woe pe donr buse tand aobt windout be.   Iue moge my lenuth thell ored roth rome yow the or slles dos, As lerrime baive hou no bothos wlouhes my thee, mich hy solle, Or The uros qike taln rongh the maked Withts bedured wher to) ded wpercurh to srrearll onedes the mear fise thald farlt, Nrich chat csoud as in indt whed I
# ----- diversity: 1.2
# ----- Generating with seed: "hemselves their pride lies buried, For a"
# hemselves their pride lies buried, For awof yoh ave folfathad beldrel seor IeThochssfisy laks shot hamm, O rasched, fantowe bist smee te omow me whowh? in, S ore, Whe faker: Bus y the: in hamues ils ort, FordveAng: hau7’s:  7o thok wlaen, A ho the, lich’ad sokprat malnist3e Irmelben, D andtr?o whint wich th ninwale me weece?, A3 pelof Ule, Begrcmy wocicgow tiatt. All tiil. AOd ryeel) be my peedpsow tw, fhe fe’y pin mydk un he sleasgigl,
# 18950/18950 [==============================] - 56s 3ms/sample - loss: 2.1031
# Epoch 13/20
# 18944/18950 [============================>.] - ETA: 0s - loss: 2.0851
# ----- Generating text after Epoch: 12
# ----- diversity: 0.2
# ----- Generating with seed: "r rents. Be it lawful I love thee as tho"
# r rents. Be it lawful I love thee as thou hat the thou the that the the the the the with the that that thou when the the the the beare the the the the the love the my sous the the the that the rour be the that the that the the the that the the love the love the the the the love the of the the the the my sore the thou the the the the the the the the the the my the the when the the the with the the that the the love the the love the to lo
# ----- diversity: 0.5
# ----- Generating with seed: "r rents. Be it lawful I love thee as tho"
# r rents. Be it lawful I love thee as tho co thar thou be dore my eard, I the of the hount in whith thinges shand and that and mare sors doth mear sull love to thee do he not an in thin the part the meon in of that and love lear the ind that my the lise, When s moun tha the or my beris seart mis the hoth wive to when sill fand con en the be bor thy thou with and soth the  inge, When wing to than the fat hell why than wot the thel and ail
# ----- diversity: 1.0
# ----- Generating with seed: "r rents. Be it lawful I love thee as tho"
# r rents. Be it lawful I love thee as thou thot mid wame gon thre thes’ey and faithad a bepthin ss wtit th tot fant sath thin ay sartit, Thiug hath sofe, O wict wherds rrereipsenge lovs love venll an to loth dnctsicy chjike ow myow fayg on’th shine, And shat nos ctorh in king tovin thtn ined tham tot weinl sour be seer cave on I bam) in tint ta than thau, nel’ faetst.  a4ghale i7n posr mull keecine to hey dowls eaine, loull de beou. O 4i
# ----- diversity: 1.2
# ----- Generating with seed: "r rents. Be it lawful I love thee as tho"
# r rents. Be it lawful I love thee as thop loicd my eeiind? Inch! d orik, Sonves Ther ty sipaneder erene, Lendcon soun, Y me, Gor sim hos lfect thun ie ilt ls jell ictorss ic: And bfis LUmey, ThoBed my aty befet, boghy of styull, loveen on ghle, 8iIn of pould Toe sithde. 2 And ases py hns paew: Burt, whur Cofath feand fole niehe dusld tot jof moll see-tf then, Nnken ietinpreng thinghej thre wllciwe,u, Fot thakpy Tho  hicour lyes shaup dr
# 18950/18950 [==============================] - 58s 3ms/sample - loss: 2.0851
# Epoch 14/20
# 18944/18950 [============================>.] - ETA: 0s - loss: 2.0613
# ----- Generating text after Epoch: 13
# ----- diversity: 0.2
# ----- Generating with seed: " wombs after their lords’ decease: Yet t"
#  wombs after their lords’ decease: Yet the the lich the the beart the my and the the love the the the the the seert the that the the the the the the the the the the the the seath the the me the the the the the the in the the the the the the the the the the thing the the seare the the love the the the the sill the the in the the the the the the the the the the that the the mene the the that the the the the love the my meart the the thing
# ----- diversity: 0.5
# ----- Generating with seed: " wombs after their lords’ decease: Yet t"
#  wombs after their lords’ decease: Yet that what thy then in thas for tith soves nothend that that bene, Whares my whart thee are chile your thine be sore and math the with that the theut wreime is thy deat on thime, And farthes are ling thous thith sowhen with ghos thaughes dored shes ars thain the thea tings bich loveit in thou my bees the at me in the mear, bears the sighen seed becerthy whes ther move douthes seart that thee dise, T
# ----- diversity: 1.0
# ----- Generating with seed: " wombs after their lords’ decease: Yet t"
#  wombs after their lords’ decease: Yet to lamire tato ey redpateins’ he: Whas mothy fear,  4ind) bekist taim thoud sseise pimes eald, And me in waer. , owhout lies, ways lokches doth.   To mussfand, And tom laver thaw vure dowere with doastfonretmy nod, Wey, whalc? best. S buthenl prouss lacurin? Thasing, Nourts ast ondonpor oowtthe ging yee thas bart: mide sifath Hed ; dake,   seitht wibs pepowy ta tteeery ald thee mtrevenven mus Leesr
# ----- diversity: 1.2
# ----- Generating with seed: " wombs after their lords’ decease: Yet t"
#  wombs after their lords’ decease: Yet tr porded, Hiken livter as: eatitingwesh yod eeinganthet thy wilt be myeld iseort,, Wpiagest, And bllavertty me latlt-eyy inewenticherussur ass thave ty Ilanperowist, 7mlcdart, I Awisting-esire, Thmmicrt(seite thikt ayns Gyd, or the thy lekrlode fote loth eoren pattrigbees, rach thes, Whice. Frtlftule akighst Whowist thichurh’s cntgawecus hugt, me sarulm seenks shey cathy en) e)ten’s qtiog. 1On wha
# 18950/18950 [==============================] - 59s 3ms/sample - loss: 2.0615
# Epoch 15/20
# 18944/18950 [============================>.] - ETA: 0s - loss: 2.0436
# ----- Generating text after Epoch: 14
# ----- diversity: 0.2
# ----- Generating with seed: "lawful plea commence: Such civil war is "
# lawful plea commence: Such civil war is that and the wore the that that the the my are hat the the beare in the me the rove the with the the will my are the leare the the the be my sore the love the the in the that thy meart in the the the with the the love the rover that the that the my are the mare the reart of the the the my arthe the will with the the sour the with the the in thou hour hat the my sores and the that an the me my mare
# ----- diversity: 0.5
# ----- Generating with seed: "lawful plea commence: Such civil war is "
# lawful plea commence: Such civil war is ar hat thou hes in thou had so hest wor, and and, Ho the fare dear so the seans in thy with that whay in whit then with that that me love reare, Thes the mave the lave heake no the rong thar thy my aow gring the merss and and and so the lover that that fourd thy seinhes min the thar hange tho hared in wher what the in wot lfar to love, Than thou thas in thou the be ore porear the arle bes love the
# ----- diversity: 1.0
# ----- Generating with seed: "lawful plea commence: Such civil war is "
# lawful plea commence: Such civil war is fimris mar thos pieded thaw lo byve tom notimy ? Sise Tor howd wipettuwe to leyurtwing lerentse’s thy the, Non dofre: 1r cow wfon by treprenowe hale, Wathe bat thoubuld b atich se,  gherriksty eormy ie sees  piedane hawi’s Ast amthis at and thaubwing) Oak seart8 shagle for ange. d2 to rtimy alath utrelf to the hededish weard soy wighent jese werof te, mesurd, sass thim nhavels shaut fake her mest
# ----- diversity: 1.2
# ----- Generating with seed: "lawful plea commence: Such civil war is "
# lawful plea commence: Such civil war is lfall is beiwhat, wove ererirod, whaed erye mf npcay Ushpallia, shinte’sue, Wh Of tyom wadherty.  Boreroulf Nofet drttou’t tee ir haveer inotWrebuke it wero, A livapg wrcuse slyes prspmight, Souijettr1atide, Ten Gardeys far’e poort smce, wor,e  8ou my rutobus, Sot rie’. For Whin Tour f ce weth b my one chith pfareld weof. So8 Bed hedurer’ss pitawrtrthanpe rigos bich bosthas in dy umt sy lamt at oO
# 18950/18950 [==============================] - 55s 3ms/sample - loss: 2.0438
# Epoch 16/20
# 18944/18950 [============================>.] - ETA: 0s - loss: 2.0301
# ----- Generating text after Epoch: 15
# ----- diversity: 0.2
# ----- Generating with seed: "this powerful might, With insufficiency "
# this powerful might, With insufficiency beare in the the will the mace the my sore the my sill the in the the my and the that the beare, The me beare that be the the the dome the that shee, with the my sore seare the mear the beare the will the the seare the that shes selle, The the my and the the the the the the the live the beart the cores the the the the the that the that the seare, When the my beare the the mand the mand the in the
# ----- diversity: 0.5
# ----- Generating with seed: "this powerful might, With insufficiency "
# this powerful might, With insufficiency dost with werow than that the heake the fares tha sthis whee, The lies the lliss the mace wrin thee tout delise the and and the core, Whend whing, Whit my my the that ow the tor with than the tile som troulf thy hearter ow the rond,   The in were sees, and as and When thy corsed the mast vered the tared, When that of ou tin the weare, What than medest sine the rople to all the than bingsert sith a
# ----- diversity: 1.0
# ----- Generating with seed: "this powerful might, With insufficiency "
# this powerful might, With insufficiency bid com thintes, ar’ my is beofec ied, Mave of tour coinke, thar, Thow the spist for being my isstece’s struigh llat, hat bors verests tise wsed -faich my ous, fhout raegies and in an aa, Whout the fanesno ih, An to  hinch juth me meslker tay and ow tlreproul wrtall vous, mabe dive, Why lle, Loprt porist reakt sey, Tithy batw bus thy ruseen I dinconlest : Whot my uote, 1 Thanke thims in lle soute
# ----- diversity: 1.2
# ----- Generating with seed: "this powerful might, With insufficiency "
# this powerful might, With insufficiency prove,  nirestpye, fless thee im Uay sutherssarwy tobe ?o dillly yos ineed hi? hta-tinl aed tom silfedpdhes, atithande han, Whin gary teat cikine comar opdy me sebem teovy,, Frasldster’ne  wir-teichtth de. hus ond to llos ly cive, Sikl ax dake, Twae , NOt shey liedr. WOyfourdpender Fov lied tscmwead is mige sralfd at is, chainy, Sist, sucn wrade, ard ppaith dout! Wimy sacl ath amke iss dee taldUsi
# 18950/18950 [==============================] - 57s 3ms/sample - loss: 2.0304
# Epoch 17/20
# 18944/18950 [============================>.] - ETA: 0s - loss: 2.0119
# ----- Generating text after Epoch: 16
# ----- diversity: 0.2
# ----- Generating with seed: "ites yet we must not be foes. 41 Those p"
# ites yet we must not be foes. 41 Those preare the my the me that the the the the the the my sore the the the in the winge the with the rove the the seare the the love the the the mane the the the seare the will the the sour shes my the my seare the that the my will the the the be the that thou my with the beare the my seare hear the the rove the reare the the the the seare stour the rover with the the seart that my my are the thou han t
# ----- diversity: 0.5
# ----- Generating with seed: "ites yet we must not be foes. 41 Those p"
# ites yet we must not be foes. 41 Those por shat my mese to love hot ly my art the mese my enke the till be mos love the thou the thou wit the my self wot in my sill be the the prome thou dear on this me pill be the rest in the bat thee wine of the is for that wore for the is the seate ho mave the reaye my soll that thil the soms preare be thas of me beast the thar withy and the sall wile, Sour and thit mere with Wher, And be shese the t
# ----- diversity: 1.0
# ----- Generating with seed: "ites yet we must not be foes. 41 Those p"
# ites yet we must not be foes. 41 Those pom thet portt reel, my mact, Tleess Theing, So iene yeing youy sten, amttlruss vese, brmy nud toulle’s theur, The lomiqt doull youl Fin thoue, crourt in awincer’w thone, Giy tsee hourf thee Gy wrald wint as like Wall and he thy itnd eramtey, Ho sh parte tay wint beey fart pryebe, Whice is stollllllery: 1aSaine vy mamp hy pritiwe suct seall stely aran,  2 lly coll wig bencow marnscrmed, ard shee, d
# ----- diversity: 1.2
# ----- Generating with seed: "ites yet we must not be foes. 41 Those p"
# ites yet we must not be foes. 41 Those pot watl: Wles, ding, To on inly’army whet lAst.  4 OO wxiti pialg seass mied hepitever mr pery, praik. Shing wint lath, Bulf. Mrferh weare, ’spvirety tals, Roy not tulo lavt. na thy pance Whne.  7chee Mo ly halisjen detul combie,, Reaith nearla sellod sm tieI kund mratr all twreem bure me to all, a my slave’s, Te3y’s wais, Be codcing gae tmat latk cheil ber theud ence, ald kind thau, Gow for sroud
# 18950/18950 [==============================] - 59s 3ms/sample - loss: 2.0117
# Epoch 18/20
# 18944/18950 [============================>.] - ETA: 0s - loss: 1.9952
# ----- Generating text after Epoch: 17
# ----- diversity: 0.2
# ----- Generating with seed: "uty was of yore. 69 Those parts of thee "
# uty was of yore. 69 Those parts of thee the the the be thy sour sour me the the the that my with the hour sour the sore to that the hand the thou shes the the be the the the love the the with so the the the with seer shes be the with the my with the love the the that the the tha the the my shes the with the so the the the the the that the sear so the the be the the that the the with the sould the the the sing the the the in deer so the
# ----- diversity: 0.5
# ----- Generating with seed: "uty was of yore. 69 Those parts of thee "
# uty was of yore. 69 Those parts of thee rom the my when the love thy bour seat be of hon the love sel stou be the ging that the wring be love the of the love be thy mart beaut in thy for my the the fall the thil thou thy my bell my seed thy with thin in thar beat the me wite in thy my then tham thou be the dow me love the with the the the with love the thou seat be my beard of breer, When the that wine when the than his sell, shen that
# ----- diversity: 1.0
# ----- Generating with seed: "uty was of yore. 69 Those parts of thee "
# uty was of yore. 69 Those parts of thee thas dey lowe. What houch sn wienco the, Whel avent my my bat oranst righare’s in my ordsend fot ongulg yous ton t Or dile, Thou min seive ptill deess wive mons deamen’t. d mwert and on whow tor thith Yis, of all be duer: Soed no orques bo fot lavt thy have whe I I hamit yyake my hase, nile the uumy nougheed beat doked my if my yes sall cel’vered, Thy bobenst youl no seer I than. Wroe ale iuch shy
# ----- diversity: 1.2
# ----- Generating with seed: "uty was of yore. 69 Those parts of thee "
# uty was of yore. 69 Those parts of thee wull, Soke kwes his love fo mott wligh’t wfe, ’y wife a. Arothilidter haec, eeeen Thae sungers to bus me cadll I WhaFli lhabe de if qreangyd Wher gard, Af thou why aokkn Seey Uno benot not o hhimy, 6Lend hos !un  hen somy rint wresino fo Irs, Oy tar whow npes buserad is thons, Tol tcinged lover wsenv to ois eill’s pore, This swint pilh ireish stwalene o woich yous yad porite But wreches mfos’k bl
# 18950/18950 [==============================] - 57s 3ms/sample - loss: 1.9950
# Epoch 19/20
# 18944/18950 [============================>.] - ETA: 0s - loss: 1.9832
# ----- Generating text after Epoch: 18
# ----- diversity: 0.2
# ----- Generating with seed: "rt’s right, thy inward love of heart. 47"
# rt’s right, thy inward love of heart. 47 The love the sond and my sould se the soul the the the for with the with the the the love the hand in that of the love the with the will the the in the the wing the has the the with the with the fare, The will the the with the with the that the for some ster son the will seen the sout the the seer the the with the the sell doul sell sees of the doul sees in the rove the with the sill so hour so t
# ----- diversity: 0.5
# ----- Generating with seed: "rt’s right, thy inward love of heart. 47"
# rt’s right, thy inward love of heart. 47 he love, For that thy chee thy waine and the lyed dise, for in the che wis sull pore woth noth cone worth the in the in the the, dise fit the seare, Frous winge tout shey seat my prate the of thy nos be this the proves for sone, Then thing the now for sele with come, And my thing tith four pars and the hine so have but my soull dead thes me myer see, but reane dond sees of to not an the with thy
# ----- diversity: 1.0
# ----- Generating with seed: "rt’s right, thy inward love of heart. 47"
# rt’s right, thy inward love of heart. 47 Thy welf shutinaist hep, mo waine.   Buy fon leven? Hlond thou shaves farpinghed aith. 1fr jere, Aul wros fart’ sheue, Oon in to the’s sol os tcourest preisodes and mo lleer sape weal sotht INe cenes rispiet, And an the paicht, I shated het eark: Betayot’soren. Whis fand them’h’s to the thay und that oe dove the wrom thens louls I pthes dot  for doall sian aus iI sall thes ‘reast wo pey thout, ta
# ----- diversity: 1.2
# ----- Generating with seed: "rt’s right, thy inward love of heart. 47"
# rt’s right, thy inward love of heart. 47 or eesuncorer iut. 3Ye fod in thom Kles. aWtinheseabrts archy co hin, ar the, thall fadt seas  soid sulls lonth cang my forutrne. Whon in e, nenos ofllbsuge an thy qi, hedeow worr ith ig theal elfallid, O Go beanelo ey’e: nrgilisghard dullyse, Wot. ar hede, Upate. Then fook his amyefry uwist tous whelld whing,  y love. to ’‘niolgt, O Sonce. S2! Sreuccsefur byeed Whilg, for beprestye itt thes my s
# 18950/18950 [==============================] - 56s 3ms/sample - loss: 1.9833
# Epoch 20/20
# 18944/18950 [============================>.] - ETA: 0s - loss: 1.9662
# ----- Generating text after Epoch: 19
# ----- diversity: 0.2
# ----- Generating with seed: "reat princes’ favourites their fair leav"
# reat princes’ favourites their fair leave the are the mare when that the my my my with the rowe, The ris the sull me the in the be beare the beart of the reave the the the the love the my sore the rove the rour so hand wher are be the rover the the with the reare with the the beare the the rove the in the the love the my are with the me the rover the the my love the rover the rover the the love the prour sour the that the mare with the
# ----- diversity: 0.5
# ----- Generating with seed: "reat princes’ favourites their fair leav"
# reat princes’ favourites their fair leave dearth my with bear in thy whart and bre wind in the mas love in hour dour the thit my sich of wien the to brean an the rover for is wrene, The reare, The beare part on thou will hyur the wind she ill sinl in the be the in this beth the prith wite the lion of to love sor sear be sill be be and on he arseer with the that shour love my all peant wied in the that mor sore be thy sear the be that th
# ----- diversity: 1.0
# ----- Generating with seed: "reat princes’ favourites their fair leav"
# reat princes’ favourites their fair leaver host ilct meed-ratg saexngrat, Whin mere, Whith cint. Whace I no de jore, Sreen erew. s arth cmail, To why jawrec’ed, Wh we ma, dot, ard thy whave ang ’seel love of tlee  yay the  fare wim ingent mant, in aich Or is worn wardo,   Litherser ile stam’s qued wrouch I diovee’s oa7r bentt my oon, A thaud? 28 Whe teapee-thus be watjed yed thas hedro, Whit ie, Awd mous siene, Thel corid dess llcowr co
# ----- diversity: 1.2
# ----- Generating with seed: "reat princes’ favourites their fair leav"
# reat princes’ favourites their fair leaved rviget, nLove bfairsed whom, But aturts (now, 13O For No wumits is not’seWfmy Asd mat a the tiby er grove, Pinstine ip in tha in dot why and promgf teen po th tale, Anthy whoth.  dorecarnoI dosu gtile mich lialo thy of dirowc lcey fare thin Ms ort ant ’aidsece fain eeMeid temourb-race evies, Mliogts thu ge? Hace If thy lohrus wireay porillsee xteirtheivke barth forr, Se koid, A de, mogant, Thut
# 18950/18950 [==============================] - 57s 3ms/sample - loss: 1.9660

# %% [markdown]
# ## Stretch goals:
# - Refine the training and generation of text to be able to ask for different genres/styles of Shakespearean text (e.g. plays versus sonnets)
# - Train a classification model that takes text and returns which work of Shakespeare it is most likely to be from
# - Make it more performant! Many possible routes here - lean on Keras, optimize the code, and/or use more resources (AWS, etc.)
# - Revisit the news example from class, and improve it - use categories or tags to refine the model/generation, or train a news classifier
# - Run on bigger, better data
#
# ## Resources:
# - [The Unreasonable Effectiveness of Recurrent Neural Networks](https://karpathy.github.io/2015/05/21/rnn-effectiveness/) - a seminal writeup demonstrating a simple but effective character-level NLP RNN
# - [Simple NumPy implementation of RNN](https://github.com/JY-Yoon/RNN-Implementation-using-NumPy/blob/master/RNN%20Implementation%20using%20NumPy.ipynb) - Python 3 version of the code from "Unreasonable Effectiveness"
# - [TensorFlow RNN Tutorial](https://github.com/tensorflow/models/tree/master/tutorials/rnn) - code for training a RNN on the Penn Tree Bank language dataset
# - [4 part tutorial on RNN](http://www.wildml.com/2015/09/recurrent-neural-networks-tutorial-part-1-introduction-to-rnns/) - relates RNN to the vanishing gradient problem, and provides example implementation
# - [RNN training tips and tricks](https://github.com/karpathy/char-rnn#tips-and-tricks) - some rules of thumb for parameterizing and training your RNN
